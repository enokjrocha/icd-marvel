# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
from IPython.core.display import HTML 


plt.ion()

# %%
dfpower = pd.read_csv('super_hero_powers.csv',index_col=0)
dfpower
# Out:
#                   Agility  Accelerated Healing  Lantern Power Ring  \
# Name
# 3-D Man              True                False               False
# A-Bomb              False                 True               False
# Abe Sapien           True                 True               False
# Abin Sur            False                False                True
# Abomination         False                 True               False
# Abraxas             False                False               False
# Absorbing Man       False                False               False
# Adam Monroe         False                 True               False
# Adam Strange        False                False               False
# Agent Bob           False                False               False
# Agent Zero          False                False               False
# Air-Walker          False                False               False
# Ajax                 True                False               False
# ...

# %%
dfinformation = pd.read_csv('heroes_information.csv', index_col=0)
_ = 0
while _ <= 733:
    if dfinformation['Publisher'][_] != 'Marvel Comics':
        dfinformation = dfinformation.drop(_)
    _ = _ + 1
    
dfinformation
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# 5      Absorbing Man    Male      blue              Human           No Hair
# 8           Agent 13  Female      blue                  -             Blond
# 9          Agent Bob    Male     brown              Human             Brown
# 10        Agent Zero    Male         -                  -                 -
# 11        Air-Walker    Male      blue                  -             White
# 12              Ajax    Male     brown             Cyborg             Black
# 20              Ammo    Male     brown              Human             Black
# 22             Angel    Male      blue                  -             Blond
# ...

# %%
dfwikia = pd.read_csv('marvel-wikia-data.csv', index_col=0)
dfwikia
# Out:
#                                                       name  \
# page_id
# 1678                             Spider-Man (Peter Parker)
# 7139                       Captain America (Steven Rogers)
# 64786                  Wolverine (James \"Logan\" Howlett)
# 1868                     Iron Man (Anthony \"Tony\" Stark)
# 2460                                   Thor (Thor Odinson)
# 2458                            Benjamin Grimm (Earth-616)
# 2166                             Reed Richards (Earth-616)
# 1833                            Hulk (Robert Bruce Banner)
# 29481                            Scott Summers (Earth-616)
# 1837                            Jonathan Storm (Earth-616)
# 15725                              Henry McCoy (Earth-616)
# 1863                               Susan Storm (Earth-616)
# 7823                            Namor McKenzie (Earth-616)
# 2614                              Ororo Munroe (Earth-616)
# 1803                            Clinton Barton (Earth-616)
# ...

# %%
count_df = (dfpower.sum()).sort_values(ascending=False)
count_df.iloc[:20].plot(kind='bar',x='Superpoder',y='Quantidade', title='Superpoderes mais comuns')

# %%
count_df = (dfpower.sum()).sort_values(ascending=True)
count_df.iloc[:20].plot(kind='bar',x='Superpoder',y='Quantidade', title='Superpoderes mais incomuns')

# %%
dataIA = dfpower[dfpower['Intuitive aptitude']] == 'True'
dataTS = dfpower[dfpower['Thirstokinesis']] == 'True'
dataHS = dfpower[dfpower['Hyperkinesis']] == 'True'

# %%
dataIA
# Out:
#        Agility  Accelerated Healing  Lantern Power Ring  \
# Name
# Sylar    False                False               False
#
#        Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# Name
# Sylar                  False            False       False    False
#
#        Energy Absorption  Flight  Danger Sense     ...      Web Creation  \
# Name                                               ...
# Sylar              False   False         False     ...             False
#
#        Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# Name
# Sylar            False       False             False        False
#
#        Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# Name
# Sylar          False                  False          False        False
#
#        Omniscient
# Name
# Sylar       False
#
# [1 rows x 167 columns]

# %%
Image(url= "http://www.clickcultural.com.br/foto/58/fto_ft1_7658.jpg")
# Out:
# <img src="http://www.clickcultural.com.br/foto/58/fto_ft1_7658.jpg"/>

# %%
dataTS
# Out:
#               Agility  Accelerated Healing  Lantern Power Ring  \
# Name
# Kool-Aid Man    False                False               False
#
#               Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# Name
# Kool-Aid Man                  False            False       False    False
#
#               Energy Absorption  Flight  Danger Sense     ...      \
# Name                                                      ...
# Kool-Aid Man              False   False         False     ...
#
#               Web Creation  Reality Warping  Odin Force  Symbiote Costume  \
# Name
# Kool-Aid Man         False            False       False             False
#
#               Speed Force  Phoenix Force  Molecular Dissipation  \
# Name
# Kool-Aid Man        False          False                  False
#
#               Vision - Cryo  Omnipresent  Omniscient
# Name
# Kool-Aid Man          False        False       False
#
# [1 rows x 167 columns]

# %%
Image(url= "https://i.pinimg.com/736x/19/b3/22/19b3227808aa2a9704b534e8a8580b61.jpg")
# Out:
# <img src="https://i.pinimg.com/736x/19/b3/22/19b3227808aa2a9704b534e8a8580b61.jpg"/>

# %%
dataHS
# Out:
#                Agility  Accelerated Healing  Lantern Power Ring  \
# hero_names
# Cameron Hicks    False                False               False
#
#                Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# hero_names
# Cameron Hicks                  False            False       False    False
#
#                Energy Absorption  Flight  Danger Sense     ...      \
# hero_names                                                 ...
# Cameron Hicks              False   False         False     ...
#
#                Web Creation  Reality Warping  Odin Force  Symbiote Costume  \
# hero_names
# Cameron Hicks         False            False       False             False
#
#                Speed Force  Phoenix Force  Molecular Dissipation  \
# hero_names
# Cameron Hicks        False          False                  False
#
#                Vision - Cryo  Omnipresent  Omniscient
# hero_names
# Cameron Hicks          False        False       False
#
# ...
